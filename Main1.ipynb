# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6876/1506572337.py in <module>
# ----> 1 import cv2
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6876/1825832018.py in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 plt.rcParams['figure.figsize'] = (12, 6)
#
# NameError: name 'plt' is not defined

# %%
img = cv2.imread('TH.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.axis("off")
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6876/2715297211.py in <module>
# ----> 1 img = cv2.imread('therock.png')
#       2 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       3
#       4 plt.axis("off")
#       5 plt.imshow(img)
#
# NameError: name 'cv2' is not defined

# %%
line_size = 7
blur_value = 7

gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray_blur = cv2.medianBlur(gray_img, blur_value)
edges = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, line_size, blur_value)


plt.axis("off")
plt.imshow(edges, cmap='gray')

# %%
k = 7
data = img.reshape(-1, 3)

kmeans = KMeans(n_clusters=k, random_state=42).fit(data)
img_reduced = kmeans.cluster_centers_[kmeans.labels_]
img_reduced = img_reduced.reshape(img.shape)

# %%
img_reduced = img_reduced.astype(np.uint8)

plt.axis("off")
plt.imshow(img_reduced)

# %%
blurred = cv2.bilateralFilter(img_reduced, d=7, sigmaColor=200,sigmaSpace=200)
TH_ = cv2.bitwise_and(blurred, blurred, mask=edges)

# %%
plt.subplot(1, 2, 1)
plt.axis("off")
plt.imshow(img)

plt.subplot(1, 2, 2)
plt.axis("off")
plt.imshow(TH_)

# %%
cartoon_ = cv2.cvtColor(TH_, cv2.COLOR_RGB2BGR)
cv2.imwrite('TH_.jpg', cartoon_)
